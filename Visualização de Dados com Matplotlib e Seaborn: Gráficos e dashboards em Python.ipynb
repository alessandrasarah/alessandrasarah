# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandrasarah/alessandrasarah/blob/main/Visualiza%C3%A7%C3%A3o%20de%20Dados%20com%20Matplotlib%20e%20Seaborn%3A%20Gr%C3%A1ficos%20e%20dashboards%20em%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# definir os dados a serem utilizados
x_line = np.linspace(0, 10, 100)
y_line = np.sin(x_line)

# %%
# gerar o gráfico de linhas ou plot

fig = plt.figure(figsize=(20, 10))
fig.set_facecolor('orange')
plt.plot(x_line, y_line)
plt.xlabel('Rótulo do eixo X')
plt.ylabel('Rótulo do eixo Y')
plt.title('Título do gráfico')
plt.show()

# %% [markdown]
# Subplot ou Subgráficos

# %%
plt.subplots(2,2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
fig, axs=plt.subplots(2,2, figsize=(10,5), layout = 'constrained')

#Cores
fig.set_facecolor('orange')
axs[0,0].set_facecolor('green')
axs[0,1].set_facecolor('purple')
axs[1,0].set_facecolor('red')
axs[1,1].set_facecolor('blue')

#Título
axs[0,0].set_title('Título 1')
axs[0,1].set_title('Título 2')
axs[1,0].set_title('Título 3')
axs[1,1].set_title('Título 4')
# Out:
# Text(0.5, 1.0, 'Título 4')

# %%
#Gráfico de barras ou Bar

#definindo os dados a serem utilizados

X =
